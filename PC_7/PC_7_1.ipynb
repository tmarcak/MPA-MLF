# %% [markdown]
# # PC 7

# %% [markdown]
# ## Convolutional Neural Network

# %%
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout
from keras.optimizers import SGD
from keras.optimizers import Adam
from keras.optimizers import Adamax
from keras.datasets import cifar10
from keras.utils import to_categorical
from keras.callbacks import EarlyStopping
from keras import regularizers

import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import cv2
import math

import tensorflow as tf

font = {'weight' : 'bold',
        'size'   : 12}

matplotlib.rc('font', **font)

# %% [markdown]
# ### Task 1

# %%
x = np.arange(0, 2*np.pi, 0.01)   # start,stop,step
y = (np.sin(x)+1)/2

x = np.expand_dims(x, -1)
y = np.expand_dims(y, -1)

plt.plot(x,y)
plt.xlabel('X Value')
plt.ylabel('Y/Predicted Value')
plt.show()

# %% [markdown]
# ### Task 2

# %%
model = Sequential()

model.add(Dense(10, input_shape=(1,), activation='tanh'))
model.add(Dense(7, activation='tanh'))
model.add(Dense(5, activation='tanh'))
model.add(Dense(3, activation='tanh'))
model.add(Dense(1, activation='tanh'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                20
#
#  dense_1 (Dense)             (None, 7)                 77
#
#  dense_2 (Dense)             (None, 5)                 40
#
#  dense_3 (Dense)             (None, 3)                 18
#
#  dense_4 (Dense)             (None, 1)                 4
#
# =================================================================
# Total params: 159
# Trainable params: 159
# Non-trainable params: 0
# _________________________________________________________________

# %%
optimizer = SGD(learning_rate=0.1)
model.compile(loss='mean_squared_error', optimizer=optimizer, metrics=['mean_squared_error'])

# %%
history = model.fit(x, y, epochs=20, batch_size=1, validation_split = 0.2)
# Out:
# Epoch 1/20
# 503/503 [==============================] - 3s 5ms/step - loss: 0.0526 - mean_squared_error: 0.0526 - val_loss: 0.1207 - val_mean_squared_error: 0.1207
# Epoch 2/20
# 503/503 [==============================] - 2s 3ms/step - loss: 0.0089 - mean_squared_error: 0.0089 - val_loss: 0.0714 - val_mean_squared_error: 0.0714
# Epoch 3/20
# 503/503 [==============================] - 2s 4ms/step - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0978 - val_mean_squared_error: 0.0978
# Epoch 4/20
# 503/503 [==============================] - 3s 6ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0862 - val_mean_squared_error: 0.0862
# Epoch 5/20
# 503/503 [==============================] - 2s 4ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0907 - val_mean_squared_error: 0.0907
# Epoch 6/20
# 503/503 [==============================] - 2s 4ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.1122 - val_mean_squared_error: 0.1122
# Epoch 7/20
# 503/503 [==============================] - 2s 4ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.1068 - val_mean_squared_error: 0.1068
# Epoch 8/20
# 503/503 [==============================] - 2s 4ms/step - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0937 - val_mean_squared_error: 0.0937
# Epoch 9/20
# 503/503 [==============================] - 1s 2ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0873 - val_mean_squared_error: 0.0873
# Epoch 10/20
# 503/503 [==============================] - 1s 2ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.1119 - val_mean_squared_error: 0.1119
# Epoch 11/20
# 503/503 [==============================] - 1s 2ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.1136 - val_mean_squared_error: 0.1136
# Epoch 12/20
# 503/503 [==============================] - 1s 3ms/step - loss: 8.5256e-04 - mean_squared_error: 8.5256e-04 - val_loss: 0.1124 - val_mean_squared_error: 0.1124
# Epoch 13/20
# 503/503 [==============================] - 1s 2ms/step - loss: 9.4798e-04 - mean_squared_error: 9.4798e-04 - val_loss: 0.1210 - val_mean_squared_error: 0.1210
# Epoch 14/20
# 503/503 [==============================] - 1s 2ms/step - loss: 8.7083e-04 - mean_squared_error: 8.7083e-04 - val_loss: 0.0971 - val_mean_squared_error: 0.0971
# Epoch 15/20
# 503/503 [==============================] - 1s 2ms/step - loss: 9.2312e-04 - mean_squared_error: 9.2312e-04 - val_loss: 0.1355 - val_mean_squared_error: 0.1355
# Epoch 16/20
# 503/503 [==============================] - 1s 2ms/step - loss: 7.2250e-04 - mean_squared_error: 7.2250e-04 - val_loss: 0.1023 - val_mean_squared_error: 0.1023
# Epoch 17/20
# 503/503 [==============================] - 1s 2ms/step - loss: 6.5998e-04 - mean_squared_error: 6.5998e-04 - val_loss: 0.1294 - val_mean_squared_error: 0.1294
# Epoch 18/20
# 503/503 [==============================] - 1s 2ms/step - loss: 6.9631e-04 - mean_squared_error: 6.9631e-04 - val_loss: 0.0967 - val_mean_squared_error: 0.0967
# Epoch 19/20
# 503/503 [==============================] - 1s 2ms/step - loss: 6.5021e-04 - mean_squared_error: 6.5021e-04 - val_loss: 0.0934 - val_mean_squared_error: 0.0934
# Epoch 20/20
# 503/503 [==============================] - 1s 2ms/step - loss: 6.0183e-04 - mean_squared_error: 6.0183e-04 - val_loss: 0.1165 - val_mean_squared_error: 0.1165

# %%
prediction = model.predict(x)
# Out:
# 20/20 [==============================] - 0s 2ms/step

# %%
plt.plot(x, prediction, x, y)
plt.xlabel('X Value')
plt.ylabel('Y/Predicted Value')
plt.show()
